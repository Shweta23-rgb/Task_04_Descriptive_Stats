# %%
import numpy as np
import pandas as pd
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/9c/9gm285k54tz9ysvymk9gtd400000gn/T/ipykernel_70670/1662815981.py", line 2, in <module>
#     import pandas as pd
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 50, in <module>
#     from pandas.core import (
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/core/ops/__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/core/computation/check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/numexpr/__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/9c/9gm285k54tz9ysvymk9gtd400000gn/T/ipykernel_70670/1662815981.py", line 2, in <module>
#     import pandas as pd
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %% [markdown]
# **Project Introduction & Data Cleaning Philosophy**
#
# **Handling Complex Columns**
#
# The original Facebook Ads dataset includes several columns with complex data types (dictionaries and lists stored as strings)—not just simple numeric or categorical values. Notable examples include:
#
# delivery_by_region (dictionary as string)
#
# demographic_distribution (dictionary as string)
#
# publisher_platforms (list as string)
#
# illuminating_mentions (list as string)
#
# **Thought Process & Rationale**
#
# For initial descriptive analytics, I decided to keep these columns as string representations rather than unpacking or flattening them into multiple columns or rows. This ensures that:
#
# The core summary statistics remain focused on the most interpretable and universally comparable fields.
#
# The dataset size and computational complexity stay manageable.
#
# Results are directly comparable across Python, Pandas, and Polars without additional transformation logic.
#
# For string/object columns, I computed standard categorical statistics (unique count, mode, top value frequencies) based on the string form.
#
# **Why not flatten initially?**
#
# Flattening dictionary/list columns (e.g., expanding delivery_by_region into one column per region) would have exploded the dataset size, especially when using only base Python.
#
# The process is highly context-dependent: different downstream analyses (aggregation, grouping) may require different unpacking strategies.
#
# For this baseline summary, I prioritized consistency and clarity.
#
# **Future Aggregations**
#
# For advanced analyses (such as aggregation by region, demographic group, or platform), I plan to unpack these columns as needed. This will involve:
#
# Converting string-encoded dictionaries/lists to real Python objects.
#
# Exploding or normalizing the dataset to long format for the relevant fields.
#
# Performing groupby/aggregation on these unpacked values.
#
# This approach keeps the base summary clean, comparable, and reproducible, while leaving the door open for targeted feature engineering when deeper analysis is needed.
#
# **Summary:**
#
# For the core descriptive statistics, I kept complex columns as strings. For advanced aggregation, I will unpack and normalize those columns as required by the analysis question.

# %%
facebook_ads = pd.read_csv("2024_fb_ads_president_scored_anon.csv")

# %%
facebook_ads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246745 entries, 0 to 246744
# Data columns (total 41 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   page_id                                    246745 non-null  object
#  1   ad_id                                      246745 non-null  object
#  2   ad_creation_time                           246745 non-null  object
#  3   bylines                                    245736 non-null  object
#  4   currency                                   246745 non-null  object
#  5   delivery_by_region                         246745 non-null  object
#  6   demographic_distribution                   246745 non-null  object
#  7   estimated_audience_size                    246745 non-null  int64
#  8   estimated_impressions                      246745 non-null  int64
#  9   estimated_spend                            246745 non-null  int64
#  10  publisher_platforms                        246745 non-null  object
#  11  illuminating_scored_message                246745 non-null  object
#  12  illuminating_mentions                      246745 non-null  object
#  13  scam_illuminating                          246745 non-null  int64
#  14  election_integrity_Truth_illuminating      246745 non-null  int64
#  15  advocacy_msg_type_illuminating             246745 non-null  int64
#  16  issue_msg_type_illuminating                246745 non-null  int64
#  17  attack_msg_type_illuminating               246745 non-null  int64
#  18  image_msg_type_illuminating                246745 non-null  int64
#  19  cta_msg_type_illuminating                  246745 non-null  int64
#  20  engagement_cta_subtype_illuminating        246745 non-null  int64
#  21  fundraising_cta_subtype_illuminating       246745 non-null  int64
#  22  voting_cta_subtype_illuminating            246745 non-null  int64
#  23  covid_topic_illuminating                   246745 non-null  int64
#  24  economy_topic_illuminating                 246745 non-null  int64
#  25  education_topic_illuminating               246745 non-null  int64
#  26  environment_topic_illuminating             246745 non-null  int64
#  27  foreign_policy_topic_illuminating          246745 non-null  int64
#  28  governance_topic_illuminating              246745 non-null  int64
#  29  health_topic_illuminating                  246745 non-null  int64
#  30  immigration_topic_illuminating             246745 non-null  int64
#  31  lgbtq_issues_topic_illuminating            246745 non-null  int64
#  32  military_topic_illuminating                246745 non-null  int64
#  33  race_and_ethnicity_topic_illuminating      246745 non-null  int64
#  34  safety_topic_illuminating                  246745 non-null  int64
#  35  social_and_cultural_topic_illuminating     246745 non-null  int64
#  36  technology_and_privacy_topic_illuminating  246745 non-null  int64
#  37  womens_issue_topic_illuminating            246745 non-null  int64
#  38  incivility_illuminating                    246745 non-null  int64
#  39  freefair_illuminating                      246745 non-null  int64
#  40  fraud_illuminating                         246745 non-null  int64
# dtypes: int64(31), object(10)
# memory usage: 77.2+ MB

# %%
import pandas as pd
import json
import ast

# Script to find dictionary/JSON columns in Facebook Ads dataset
print("=== FINDING DICTIONARY COLUMNS ===")

# Get all object columns
object_columns = facebook_ads.select_dtypes(include=['object']).columns
print(f"Object columns to check: {list(object_columns)}")

def check_for_dictionaries(df, column):
    """Check if a column contains dictionaries or JSON structures"""
    print(f"\n--- {column} ---")
    
    # Get first 3 non-null values
    sample_values = df[column].dropna().head(3).tolist()
    
    has_dicts = False
    has_lists = False
    
    for i, val in enumerate(sample_values):
        print(f"Sample {i+1}: {str(val)[:100]}...")
        print(f"Type: {type(val).__name__}")
        
        if isinstance(val, str):
            # Check if it looks like JSON
            if val.strip().startswith('{'):
                try:
                    parsed = json.loads(val)
                    if isinstance(parsed, dict):
                        has_dicts = True
                        print(f"  DICTIONARY detected with keys: {list(parsed.keys())}")
                except:
                    try:
                        parsed = ast.literal_eval(val)
                        if isinstance(parsed, dict):
                            has_dicts = True
                            print(f"  PYTHON DICT detected with keys: {list(parsed.keys())}")
                    except:
                        print("  Looks like dict but can't parse")
            elif val.strip().startswith('['):
                try:
                    parsed = json.loads(val)
                    if isinstance(parsed, list):
                        has_lists = True
                        print(f"  LIST detected with {len(parsed)} items")
                except:
                    try:
                        parsed = ast.literal_eval(val)
                        if isinstance(parsed, list):
                            has_lists = True
                            print(f"  PYTHON LIST detected with {len(parsed)} items")
                    except:
                        print("  Looks like list but can't parse")
            else:
                print("  Regular string")
    
    if has_dicts:
        print("  CONTAINS DICTIONARIES")
        return "DICTIONARY"
    elif has_lists:
        print("  CONTAINS LISTS")
        return "LIST"
    else:
        print("  Just regular strings")
        return "STRING"

# Check each object column
print("\nChecking each object column for complex data structures:")

results = {}
for col in object_columns:
    result = check_for_dictionaries(facebook_ads, col)
    results[col] = result

# Summary
print("\n" + "=" * 50)
print("SUMMARY")
print("=" * 50)

dict_columns = [k for k, v in results.items() if v == "DICTIONARY"]
list_columns = [k for k, v in results.items() if v == "LIST"]
string_columns = [k for k, v in results.items() if v == "STRING"]

print(f"Dictionary columns: {dict_columns}")
print(f"List columns: {list_columns}")
print(f"Simple string columns: {string_columns}")

print(f"\nTotal complex columns to handle: {len(dict_columns) + len(list_columns)}")
# Out:
# === FINDING DICTIONARY COLUMNS ===
# Object columns to check: ['page_id', 'ad_id', 'ad_creation_time', 'bylines', 'currency', 'delivery_by_region', 'demographic_distribution', 'publisher_platforms', 'illuminating_scored_message', 'illuminating_mentions']
#
# Checking each object column for complex data structures:
#
# --- page_id ---
# Sample 1: 4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230...
# Type: str
#   Regular string
# Sample 2: 4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230...
# Type: str
#   Regular string
# Sample 3: 4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230...
# Type: str
#   Regular string
#   Just regular strings
#
# --- ad_id ---
# Sample 1: 0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc...
# Type: str
#   Regular string
# Sample 2: 86229868e6bde3661724fe02da93504bb4fb5da8c2550d7b7cf193c687e89fa6...
# Type: str
#   Regular string
# Sample 3: 07b5aefc27e872e971f793e49aac38496fa62e484f3928e2b6a2b6e3e08cac8d...
# Type: str
#   Regular string
#   Just regular strings
#
# --- ad_creation_time ---
# Sample 1: 2024-10-21...
# Type: str
#   Regular string
# Sample 2: 2024-10-18...
# Type: str
#   Regular string
# Sample 3: 2024-10-13...
# Type: str
#   Regular string
#   Just regular strings
#
# --- bylines ---
# Sample 1: Texas Organizing Project PAC...
# Type: str
#   Regular string
# Sample 2: Texas Organizing Project PAC...
# Type: str
#   Regular string
# Sample 3: Texas Organizing Project PAC...
# Type: str
#   Regular string
#   Just regular strings
#
# --- currency ---
# Sample 1: USD...
# Type: str
#   Regular string
# Sample 2: USD...
# Type: str
#   Regular string
# Sample 3: USD...
# Type: str
#   Regular string
#   Just regular strings
#
# --- delivery_by_region ---
# Sample 1: {'Texas': {'spend': 249, 'impressions': 47499}}...
# Type: str
#   PYTHON DICT detected with keys: ['Texas']
# Sample 2: {'Texas': {'spend': 49, 'impressions': 22499}}...
# Type: str
#   PYTHON DICT detected with keys: ['Texas']
# Sample 3: {'Texas': {'spend': 149, 'impressions': 32499}}...
# Type: str
#   PYTHON DICT detected with keys: ['Texas']
#   CONTAINS DICTIONARIES
#
# --- demographic_distribution ---
# Sample 1: {'female_18-24': {'spend': 28, 'impressions': 5507}, 'male_45-54': {'spend': 14, 'impressions': 2757...
# Type: str
#   PYTHON DICT detected with keys: ['female_18-24', 'male_45-54', 'male_65+', 'female_65+', 'unknown_55-64', 'male_55-64', 'female_55-64', 'unknown_45-54', 'female_45-54', 'male_18-24', 'unknown_35-44', 'male_35-44', 'female_35-44', 'unknown_25-34', 'male_25-34', 'female_25-34', 'unknown_18-24', 'unknown_65+']
# Sample 2: {'female_18-24': {'spend': 8, 'impressions': 3904}, 'male_45-54': {'spend': 2, 'impressions': 1129},...
# Type: str
#   PYTHON DICT detected with keys: ['female_18-24', 'male_45-54', 'male_65+', 'female_65+', 'unknown_55-64', 'male_55-64', 'female_55-64', 'unknown_45-54', 'female_45-54', 'male_18-24', 'unknown_35-44', 'male_35-44', 'female_35-44', 'unknown_25-34', 'male_25-34', 'female_25-34', 'unknown_18-24', 'unknown_65+']
# Sample 3: {'female_18-24': {'spend': 26, 'impressions': 5791}, 'male_45-54': {'spend': 7, 'impressions': 1573}...
# Type: str
#   PYTHON DICT detected with keys: ['female_18-24', 'male_45-54', 'male_65+', 'female_65+', 'unknown_55-64', 'male_55-64', 'female_55-64', 'unknown_45-54', 'female_45-54', 'male_18-24', 'unknown_35-44', 'male_35-44', 'female_35-44', 'unknown_25-34', 'male_25-34', 'female_25-34', 'unknown_18-24', 'unknown_65+']
#   CONTAINS DICTIONARIES
#
# --- publisher_platforms ---
# Sample 1: ['facebook', 'instagram']...
# Type: str
#   PYTHON LIST detected with 2 items
# Sample 2: ['facebook', 'instagram']...
# Type: str
#   PYTHON LIST detected with 2 items
# Sample 3: ['facebook', 'instagram']...
# Type: str
#   PYTHON LIST detected with 2 items
#   CONTAINS LISTS
#
# --- illuminating_scored_message ---
# Sample 1: 362d68d42e34e070bc9f999033642b8fddfca5404195fc27690c60e0acde1d5b...
# Type: str
#   Regular string
# Sample 2: dc522d5aa4f91c326d105ec4c482cf4b0c378161a6438a4c604061979c49f0dc...
# Type: str
#   Regular string
# Sample 3: 6dc61896f4a44cf4fdbe564604bbebe33b84d2dbfb8bacc761b345b2879f0804...
# Type: str
#   Regular string
#   Just regular strings
#
# --- illuminating_mentions ---
# Sample 1: ['Kamala Harris', 'Tim Walz']...
# Type: str
#   PYTHON LIST detected with 2 items
# Sample 2: ['Kamala Harris', 'Tim Walz']...
# Type: str
#   PYTHON LIST detected with 2 items
# Sample 3: ['Kamala Harris', 'Tim Walz']...
# Type: str
#   PYTHON LIST detected with 2 items
#   CONTAINS LISTS
#
# ==================================================
# SUMMARY
# ==================================================
# Dictionary columns: ['delivery_by_region', 'demographic_distribution']
# List columns: ['publisher_platforms', 'illuminating_mentions']
# Simple string columns: ['page_id', 'ad_id', 'ad_creation_time', 'bylines', 'currency', 'illuminating_scored_message']
#
# Total complex columns to handle: 4

# %% [markdown]
# ## USING PANDAS:

# %%
import pandas as pd

pd.set_option('display.max_columns', None)   # Show all columns in output
pd.set_option('display.width', 150)  

pd.set_option('display.float_format', lambda x: f'{x:.3f}')  # Limit floats to 3 decimals

# Making a copy to avoid altering your original data
df_summary = facebook_ads.copy()

# Listing the columns that are dicts or lists (update if you find more)
complex_cols = ['delivery_by_region', 'demographic_distribution', 'publisher_platforms', 'illuminating_mentions']

# Converting complex columns to string for summary stats
for col in complex_cols:
    df_summary[col] = df_summary[col].astype(str)

# ---------------------------------------------------------
# NUMERIC SUMMARY
# ---------------------------------------------------------
print("\n=== NUMERIC SUMMARY ===")
numeric_summary = df_summary.describe(include=[int, float])
print(numeric_summary)

# ---------------------------------------------------------
# CATEGORICAL/OBJECT SUMMARY
# ---------------------------------------------------------
print("\n=== CATEGORICAL SUMMARY ===")
object_columns = df_summary.select_dtypes(include='object').columns

for col in object_columns:
    nunique = df_summary[col].nunique(dropna=True)
    print(f"\nColumn: {col}")
    print(f"  Unique values: {nunique}")
    most_freq = df_summary[col].mode(dropna=True)
    mf_val = most_freq.iloc[0] if not most_freq.empty else None
    print(f"  Most frequent: {mf_val}")
    vc = df_summary[col].value_counts(dropna=True)
    print(f"  Top 5 value counts:")
    print(vc.head())

# ---------------------------------------------------------
# OPTIONAL: Save summaries to CSV
# ---------------------------------------------------------
# numeric_summary.to_csv("facebook_numeric_summary.csv")
# Out:
# === NUMERIC SUMMARY ===
#        estimated_audience_size  estimated_impressions  estimated_spend  scam_illuminating  election_integrity_Truth_illuminating  \
# count               246745.000             246745.000       246745.000         246745.000                             246745.000
# mean                556462.856              45601.526         1061.291              0.072                                  0.050
# std                 409864.759             136790.770         4992.561              0.258                                  0.218
# min                      0.000                499.000           49.000              0.000                                  0.000
# 25%                  75000.000                499.000           49.000              0.000                                  0.000
# 50%                 300000.000               3499.000           49.000              0.000                                  0.000
# 75%                1000001.000              22499.000          449.000              0.000                                  0.000
# max                1000001.000            1000000.000       474999.000              1.000                                  1.000
#
#        advocacy_msg_type_illuminating  issue_msg_type_illuminating  attack_msg_type_illuminating  image_msg_type_illuminating  \
# count                      246745.000                   246745.000                    246745.000                   246745.000
# mean                            0.549                        0.382                         0.272                        0.223
# std                             0.498                        0.486                         0.445                        0.416
# min                             0.000                        0.000                         0.000                        0.000
# 25%                             0.000                        0.000                         0.000                        0.000
# 50%                             1.000                        0.000                         0.000                        0.000
# 75%                             1.000                        1.000                         1.000                        0.000
# max                             1.000                        1.000                         1.000                        1.000
#
#        cta_msg_type_illuminating  engagement_cta_subtype_illuminating  fundraising_cta_subtype_illuminating  voting_cta_subtype_illuminating  \
# count                 246745.000                           246745.000                            246745.000                       246745.000
# mean                       0.573                                0.125                                 0.228                            0.144
# std                        0.495                                0.331                                 0.420                            0.351
# min                        0.000                                0.000                                 0.000                            0.000
# 25%                        0.000                                0.000                                 0.000                            0.000
# 50%                        1.000                                0.000                                 0.000                            0.000
# 75%                        1.000                                0.000                                 0.000                            0.000
# max                        1.000                                1.000                                 1.000                            1.000
#
#        covid_topic_illuminating  economy_topic_illuminating  education_topic_illuminating  environment_topic_illuminating  \
# count                246745.000                  246745.000                    246745.000                      246745.000
# mean                      0.025                       0.122                         0.014                           0.021
# std                       0.156                       0.327                         0.119                           0.144
# min                       0.000                       0.000                         0.000                           0.000
# 25%                       0.000                       0.000                         0.000                           0.000
# 50%                       0.000                       0.000                         0.000                           0.000
# 75%                       0.000                       0.000                         0.000                           0.000
# max                       1.000                       1.000                         1.000                           1.000
#
#        foreign_policy_topic_illuminating  governance_topic_illuminating  health_topic_illuminating  immigration_topic_illuminating  \
# count                         246745.000                     246745.000                 246745.000                      246745.000
# mean                               0.005                          0.026                      0.109                           0.034
# std                                0.072                          0.158                      0.312                           0.180
# min                                0.000                          0.000                      0.000                           0.000
# 25%                                0.000                          0.000                      0.000                           0.000
# 50%                                0.000                          0.000                      0.000                           0.000
# 75%                                0.000                          0.000                      0.000                           0.000
# max                                1.000                          1.000                      1.000                           1.000
#
#        lgbtq_issues_topic_illuminating  military_topic_illuminating  race_and_ethnicity_topic_illuminating  safety_topic_illuminating  \
# count                       246745.000                   246745.000                             246745.000                 246745.000
# mean                             0.003                        0.002                                  0.012                      0.034
# std                              0.057                        0.047                                  0.111                      0.181
# min                              0.000                        0.000                                  0.000                      0.000
# 25%                              0.000                        0.000                                  0.000                      0.000
# 50%                              0.000                        0.000                                  0.000                      0.000
# 75%                              0.000                        0.000                                  0.000                      0.000
# max                              1.000                        1.000                                  1.000                      1.000
#
#        social_and_cultural_topic_illuminating  technology_and_privacy_topic_illuminating  womens_issue_topic_illuminating  incivility_illuminating  \
# count                              246745.000                                 246745.000                       246745.000               246745.000
# mean                                    0.106                                      0.001                            0.081                    0.188
# std                                     0.308                                      0.034                            0.273                    0.390
# min                                     0.000                                      0.000                            0.000                    0.000
# 25%                                     0.000                                      0.000                            0.000                    0.000
# 50%                                     0.000                                      0.000                            0.000                    0.000
# 75%                                     0.000                                      0.000                            0.000                    0.000
# max                                     1.000                                      1.000                            1.000                    1.000
#
#        freefair_illuminating  fraud_illuminating
# count             246745.000          246745.000
# mean                   0.006               0.003
# std                    0.080               0.051
# min                    0.000               0.000
# 25%                    0.000               0.000
# 50%                    0.000               0.000
# 75%                    0.000               0.000
# max                    1.000               1.000
#
# === CATEGORICAL SUMMARY ===
#
# Column: page_id
#   Unique values: 4475
#   Most frequent: 4d66f5853f0365dba032a87704a634f023d15babde973bb7a284ed8cd2707b2d
#   Top 5 value counts:
# page_id
# 4d66f5853f0365dba032a87704a634f023d15babde973bb7a284ed8cd2707b2d    55503
# e3342051b60393770363ffc02946a0f76bc3e4155190d1f05fb0277b34bf6480    23988
# 4ade404186269ec62d2dd7d9e0ed5f93a5f32c057516879d627ea9fbd628ef9b    14822
# 330b2f35ded2161e63fbb2b5c5bdae05bff274ff31f990c275d28ce408671ce0    10461
# ec8ac6dc1cddc49972de2c31b62343fe3979729ec437c3b8d6ffa8915ab1401d     9851
# Name: count, dtype: int64
#
# Column: ad_id
#   Unique values: 246745
#   Most frequent: 0000a88a64484883df6ca1fabd357e4c5950e443123ce3f45d1c5b4c621f9783
#   Top 5 value counts:
# ad_id
# 0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc    1
# 329368f2aa4e55f382777eeb9076b6dc15d27129adc7546a6c2366c1294820d9    1
# 2c055606917671911ca27cd4a152aea8294c227696bbfc8c7110c979369e7987    1
# 827620adb660bd50f856a2953ea6e8346aa9e85183d24b39e5feb66a9827c3cc    1
# 2e724cb4530a0da3f5fc6247251056dfe0001390e456d8bfed4af66d9878a009    1
# Name: count, dtype: int64
#
# Column: ad_creation_time
#   Unique values: 547
#   Most frequent: 2024-10-27
#   Top 5 value counts:
# ad_creation_time
# 2024-10-27    8619
# 2024-10-28    7356
# 2024-10-26    6414
# 2024-10-23    5021
# 2024-10-25    4769
# Name: count, dtype: int64
#
# Column: bylines
#   Unique values: 3790
#   Most frequent: HARRIS FOR PRESIDENT
#   Top 5 value counts:
# bylines
# HARRIS FOR PRESIDENT                        49788
# HARRIS VICTORY FUND                         32612
# BIDEN VICTORY FUND                          15539
# DONALD J. TRUMP FOR PRESIDENT 2024, INC.    15112
# Trump National Committee JFC                 7279
# Name: count, dtype: int64
#
# Column: currency
#   Unique values: 18
#   Most frequent: USD
#   Top 5 value counts:
# currency
# USD    246599
# INR        63
# GBP        17
# EUR        11
# PKR         8
# Name: count, dtype: int64
#
# Column: delivery_by_region
#   Unique values: 141122
#   Most frequent: {}
#   Top 5 value counts:
# delivery_by_region
# {}                                                     30989
# {'Georgia': {'spend': 49, 'impressions': 499}}          2307
# {'Arizona': {'spend': 49, 'impressions': 499}}          2020
# {'Pennsylvania': {'spend': 49, 'impressions': 499}}     1912
# {'Nevada': {'spend': 49, 'impressions': 499}}           1870
# Name: count, dtype: int64
#
# Column: demographic_distribution
#   Unique values: 215622
#   Most frequent: {}
#   Top 5 value counts:
# demographic_distribution
# {}                                                    30989
# {'female_65+': {'spend': 49, 'impressions': 499}}        44
# {'male_65+': {'spend': 49, 'impressions': 499}}          24
# {'female_65+': {'spend': 49, 'impressions': 1499}}       13
# {'female_65+': {'spend': 49, 'impressions': 2499}}       12
# Name: count, dtype: int64
#
# Column: publisher_platforms
#   Unique values: 9
#   Most frequent: ['facebook', 'instagram']
#   Top 5 value counts:
# publisher_platforms
# ['facebook', 'instagram']                                     214434
# ['facebook']                                                   23259
# ['instagram']                                                   8395
# ['facebook', 'instagram', 'audience_network', 'messenger']       459
# ['facebook', 'instagram', 'audience_network']                     79
# Name: count, dtype: int64
#
# Column: illuminating_scored_message
#   Unique values: 26338
#   Most frequent: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
#   Top 5 value counts:
# illuminating_scored_message
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855    5972
# 82459467ad44f717f2089911f5210cce1ff025dc0cee03bdb2e60da827edb282    1887
# 3b1d236346df93fd259a23d523f6deeed9b9939158b6f34b11854ea0f97ef35d    1352
# 7e119dac6ca701d8070d0ca8c5b480f016523cb1b78748ee27d69e71c5017f8d    1341
# 8e1144f0b13549c2652e19f6dd1ae523956a19671c5e4383a31f09d9325f1239    1172
# Name: count, dtype: int64
#
# Column: illuminating_mentions
#   Unique values: 278
#   Most frequent: []
#   Top 5 value counts:
# illuminating_mentions
# []                     73205
# ['Donald Trump']       53182
# ['Kamala Harris']      31019
# ['President Trump']    14580
# ['Joe Biden']          14059
# Name: count, dtype: int64

# %% [markdown]
# ## With Just Python:

# %%
import csv
from collections import Counter

filename = '2024_fb_ads_president_scored_anon.csv' 

def is_float(val):
    try:
        float(val)
        return True
    except (ValueError, TypeError):
        return False

# First pass: Read data and infer types per column
with open(filename, 'r', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    data = list(reader)

columns = data[0].keys()
numeric_cols = []
categorical_cols = []

# Determine column types: numeric if ALL values (ignoring blanks) are floats
for col in columns:
    values = [row[col] for row in data if row[col] not in (None, '', 'NA', 'nan')]
    if len(values) > 0 and all(is_float(v) for v in values):
        numeric_cols.append(col)
    else:
        categorical_cols.append(col)

# --- Print numeric columns summary ---
print("=== NUMERIC COLUMNS SUMMARY ===")
for col in numeric_cols:
    values = [float(row[col]) for row in data if is_float(row[col])]
    count = len(values)
    if count == 0:
        continue
    mean = sum(values) / count
    minv = min(values)
    maxv = max(values)
    std = (sum((x - mean) ** 2 for x in values) / count) ** 0.5
    print(f"\n{col}:")
    print(f"  Count: {count}")
    print(f"  Mean: {mean:.3f}")
    print(f"  Min: {minv:.3f}")
    print(f"  Max: {maxv:.3f}")
    print(f"  Std: {std:.3f}")

# --- Print categorical/object columns summary ---
print("\n=== CATEGORICAL COLUMNS SUMMARY ===")
for col in categorical_cols:
    values = [row[col] for row in data if row[col] not in (None, '', 'NA', 'nan')]
    count = len(values)
    unique = set(values)
    counter = Counter(values)
    most_common = counter.most_common(1)[0] if counter else (None, 0)
    print(f"\n{col}:")
    print(f"  Count: {count}")
    print(f"  Unique values: {len(unique)}")
    print(f"  Most frequent: {most_common[0]} ({most_common[1]})")
    print(f"  Top 5 value counts: {counter.most_common(5)}")
# Out:
# === NUMERIC COLUMNS SUMMARY ===
#
# estimated_audience_size:
#   Count: 246745
#   Mean: 556462.856
#   Min: 0.000
#   Max: 1000001.000
#   Std: 409863.928
#
# estimated_impressions:
#   Count: 246745
#   Mean: 45601.526
#   Min: 499.000
#   Max: 1000000.000
#   Std: 136790.493
#
# estimated_spend:
#   Count: 246745
#   Mean: 1061.291
#   Min: 49.000
#   Max: 474999.000
#   Std: 4992.551
#
# scam_illuminating:
#   Count: 246745
#   Mean: 0.072
#   Min: 0.000
#   Max: 1.000
#   Std: 0.258
#
# election_integrity_Truth_illuminating:
#   Count: 246745
#   Mean: 0.050
#   Min: 0.000
#   Max: 1.000
#   Std: 0.218
#
# advocacy_msg_type_illuminating:
#   Count: 246745
#   Mean: 0.549
#   Min: 0.000
#   Max: 1.000
#   Std: 0.498
#
# issue_msg_type_illuminating:
#   Count: 246745
#   Mean: 0.382
#   Min: 0.000
#   Max: 1.000
#   Std: 0.486
#
# attack_msg_type_illuminating:
#   Count: 246745
#   Mean: 0.272
#   Min: 0.000
#   Max: 1.000
#   Std: 0.445
#
# image_msg_type_illuminating:
#   Count: 246745
#   Mean: 0.223
#   Min: 0.000
#   Max: 1.000
#   Std: 0.416
#
# cta_msg_type_illuminating:
#   Count: 246745
#   Mean: 0.573
#   Min: 0.000
#   Max: 1.000
#   Std: 0.495
#
# engagement_cta_subtype_illuminating:
#   Count: 246745
#   Mean: 0.125
#   Min: 0.000
#   Max: 1.000
#   Std: 0.331
#
# fundraising_cta_subtype_illuminating:
#   Count: 246745
#   Mean: 0.228
#   Min: 0.000
#   Max: 1.000
#   Std: 0.420
#
# voting_cta_subtype_illuminating:
#   Count: 246745
#   Mean: 0.144
#   Min: 0.000
#   Max: 1.000
#   Std: 0.351
#
# covid_topic_illuminating:
#   Count: 246745
#   Mean: 0.025
#   Min: 0.000
#   Max: 1.000
#   Std: 0.156
#
# economy_topic_illuminating:
#   Count: 246745
#   Mean: 0.122
#   Min: 0.000
#   Max: 1.000
#   Std: 0.327
#
# education_topic_illuminating:
#   Count: 246745
#   Mean: 0.014
#   Min: 0.000
#   Max: 1.000
#   Std: 0.119
#
# environment_topic_illuminating:
#   Count: 246745
#   Mean: 0.021
#   Min: 0.000
#   Max: 1.000
#   Std: 0.144
#
# foreign_policy_topic_illuminating:
#   Count: 246745
#   Mean: 0.005
#   Min: 0.000
#   Max: 1.000
#   Std: 0.072
#
# governance_topic_illuminating:
#   Count: 246745
#   Mean: 0.026
#   Min: 0.000
#   Max: 1.000
#   Std: 0.158
#
# health_topic_illuminating:
#   Count: 246745
#   Mean: 0.109
#   Min: 0.000
#   Max: 1.000
#   Std: 0.312
#
# immigration_topic_illuminating:
#   Count: 246745
#   Mean: 0.034
#   Min: 0.000
#   Max: 1.000
#   Std: 0.180
#
# lgbtq_issues_topic_illuminating:
#   Count: 246745
#   Mean: 0.003
#   Min: 0.000
#   Max: 1.000
#   Std: 0.057
#
# military_topic_illuminating:
#   Count: 246745
#   Mean: 0.002
#   Min: 0.000
#   Max: 1.000
#   Std: 0.047
#
# race_and_ethnicity_topic_illuminating:
#   Count: 246745
#   Mean: 0.012
#   Min: 0.000
#   Max: 1.000
#   Std: 0.111
#
# safety_topic_illuminating:
#   Count: 246745
#   Mean: 0.034
#   Min: 0.000
#   Max: 1.000
#   Std: 0.181
#
# social_and_cultural_topic_illuminating:
#   Count: 246745
#   Mean: 0.106
#   Min: 0.000
#   Max: 1.000
#   Std: 0.308
#
# technology_and_privacy_topic_illuminating:
#   Count: 246745
#   Mean: 0.001
#   Min: 0.000
#   Max: 1.000
#   Std: 0.034
#
# womens_issue_topic_illuminating:
#   Count: 246745
#   Mean: 0.081
#   Min: 0.000
#   Max: 1.000
#   Std: 0.273
#
# incivility_illuminating:
#   Count: 246745
#   Mean: 0.188
#   Min: 0.000
#   Max: 1.000
#   Std: 0.390
#
# freefair_illuminating:
#   Count: 246745
#   Mean: 0.006
#   Min: 0.000
#   Max: 1.000
#   Std: 0.080
#
# fraud_illuminating:
#   Count: 246745
#   Mean: 0.003
#   Min: 0.000
#   Max: 1.000
#   Std: 0.051
#
# === CATEGORICAL COLUMNS SUMMARY ===
#
# page_id:
#   Count: 246745
#   Unique values: 4475
#   Most frequent: 4d66f5853f0365dba032a87704a634f023d15babde973bb7a284ed8cd2707b2d (55503)
#   Top 5 value counts: [('4d66f5853f0365dba032a87704a634f023d15babde973bb7a284ed8cd2707b2d', 55503), ('e3342051b60393770363ffc02946a0f76bc3e4155190d1f05fb0277b34bf6480', 23988), ('4ade404186269ec62d2dd7d9e0ed5f93a5f32c057516879d627ea9fbd628ef9b', 14822), ('330b2f35ded2161e63fbb2b5c5bdae05bff274ff31f990c275d28ce408671ce0', 10461), ('ec8ac6dc1cddc49972de2c31b62343fe3979729ec437c3b8d6ffa8915ab1401d', 9851)]
#
# ad_id:
#   Count: 246745
#   Unique values: 246745
#   Most frequent: 0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc (1)
#   Top 5 value counts: [('0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc', 1), ('86229868e6bde3661724fe02da93504bb4fb5da8c2550d7b7cf193c687e89fa6', 1), ('07b5aefc27e872e971f793e49aac38496fa62e484f3928e2b6a2b6e3e08cac8d', 1), ('c62978153c04116d88ead49379916855f2cb58bf788631f26f3f1fcb2962ad48', 1), ('785e91ef18a5794565af03a6df4e7077fe1d915bfb34025019f3d42f43fcf9e8', 1)]
#
# ad_creation_time:
#   Count: 246745
#   Unique values: 547
#   Most frequent: 2024-10-27 (8619)
#   Top 5 value counts: [('2024-10-27', 8619), ('2024-10-28', 7356), ('2024-10-26', 6414), ('2024-10-23', 5021), ('2024-10-25', 4769)]
#
# bylines:
#   Count: 245736
#   Unique values: 3790
#   Most frequent: HARRIS FOR PRESIDENT (49788)
#   Top 5 value counts: [('HARRIS FOR PRESIDENT', 49788), ('HARRIS VICTORY FUND', 32612), ('BIDEN VICTORY FUND', 15539), ('DONALD J. TRUMP FOR PRESIDENT 2024, INC.', 15112), ('Trump National Committee JFC', 7279)]
#
# currency:
#   Count: 246745
#   Unique values: 18
#   Most frequent: USD (246599)
#   Top 5 value counts: [('USD', 246599), ('INR', 63), ('GBP', 17), ('EUR', 11), ('PKR', 8)]
#
# delivery_by_region:
#   Count: 246745
#   Unique values: 141122
#   Most frequent: {} (30989)
#   Top 5 value counts: [('{}', 30989), ("{'Georgia': {'spend': 49, 'impressions': 499}}", 2307), ("{'Arizona': {'spend': 49, 'impressions': 499}}", 2020), ("{'Pennsylvania': {'spend': 49, 'impressions': 499}}", 1912), ("{'Nevada': {'spend': 49, 'impressions': 499}}", 1870)]
#
# demographic_distribution:
#   Count: 246745
#   Unique values: 215622
#   Most frequent: {} (30989)
#   Top 5 value counts: [('{}', 30989), ("{'female_65+': {'spend': 49, 'impressions': 499}}", 44), ("{'male_65+': {'spend': 49, 'impressions': 499}}", 24), ("{'female_65+': {'spend': 49, 'impressions': 1499}}", 13), ("{'female_65+': {'spend': 49, 'impressions': 2499}}", 12)]
#
# publisher_platforms:
#   Count: 246745
#   Unique values: 9
#   Most frequent: ['facebook', 'instagram'] (214434)
#   Top 5 value counts: [("['facebook', 'instagram']", 214434), ("['facebook']", 23259), ("['instagram']", 8395), ("['facebook', 'instagram', 'audience_network', 'messenger']", 459), ("['facebook', 'instagram', 'audience_network']", 79)]
#
# illuminating_scored_message:
#   Count: 246745
#   Unique values: 26338
#   Most frequent: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855 (5972)
#   Top 5 value counts: [('e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 5972), ('82459467ad44f717f2089911f5210cce1ff025dc0cee03bdb2e60da827edb282', 1887), ('3b1d236346df93fd259a23d523f6deeed9b9939158b6f34b11854ea0f97ef35d', 1352), ('7e119dac6ca701d8070d0ca8c5b480f016523cb1b78748ee27d69e71c5017f8d', 1341), ('8e1144f0b13549c2652e19f6dd1ae523956a19671c5e4383a31f09d9325f1239', 1172)]
#
# illuminating_mentions:
#   Count: 246745
#   Unique values: 278
#   Most frequent: [] (73205)
#   Top 5 value counts: [('[]', 73205), ("['Donald Trump']", 53182), ("['Kamala Harris']", 31019), ("['President Trump']", 14580), ("['Joe Biden']", 14059)]

# %% [markdown]
# # Descriptive Statistics: Pure Python vs Pandas
#
# | Metric                     | Pure Python Result | Pandas Result | Notes |
# |----------------------------|-------------------|---------------|-------|
# | Numeric Counts             | Identical         | Identical     |       |
# | Means, Std, Min, Max       | Identical         | Identical     |       |
# | Categorical Unique Values  | Identical         | Identical     |       |
# | Most Frequent Values       | Identical         | Identical     | Minor formatting differences |
# | Top 5 Value Counts         | Identical         | Identical     |       |
# | Handling of Dict/List Cols | Treated as str    | Treated as str| Unless explicitly unpacked   |
#
# **Summary:**
# Pandas and pure Python both yield identical results on raw summary statistics for this dataset, with Pandas being easier to use and better for large data.

# %%
# !pip install polars
# Out:
# Requirement already satisfied: polars in /Users/saiswethalakkoju/anaconda3/lib/python3.11/site-packages (1.31.0)

# %%
import polars as pl

pl.Config.set_tbl_cols(50)  
pl.Config.set_tbl_rows(20)


# Replace with your path if needed
filename = "2024_fb_ads_president_scored_anon.csv"
df = pl.read_csv(filename)

# %%
import polars as pl

df = pl.read_csv("2024_fb_ads_president_scored_anon.csv")
non_numeric_cols = [col for col, dtype in zip(df.columns, df.dtypes) if dtype == pl.Utf8]

for col in non_numeric_cols:
    nunique = df[col].n_unique()
    most_freq = df[col].mode()
    value_counts = df[col].value_counts().sort("count", descending=True)
    
    print(f"\n=== Column: {col} ===")
    print(f"  Unique values: {nunique}")
    # SAFELY extract most frequent value (works even if empty)
    if most_freq.len() > 0:
        print(f"  Most frequent: {most_freq[0]}")
    else:
        print("  Most frequent: N/A")
    print("  Top 5 value counts:")
    print(value_counts.head(5))
# Out:
# === Column: page_id ===
#   Unique values: 4475
#   Most frequent: 4d66f5853f0365dba032a87704a634f023d15babde973bb7a284ed8cd2707b2d
#   Top 5 value counts:
# shape: (5, 2)
# ┌─────────────────────────────────┬───────┐
# │ page_id                         ┆ count │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ 4d66f5853f0365dba032a87704a634… ┆ 55503 │
# │ e3342051b60393770363ffc02946a0… ┆ 23988 │
# │ 4ade404186269ec62d2dd7d9e0ed5f… ┆ 14822 │
# │ 330b2f35ded2161e63fbb2b5c5bdae… ┆ 10461 │
# │ ec8ac6dc1cddc49972de2c31b62343… ┆ 9851  │
# └─────────────────────────────────┴───────┘
#
# === Column: ad_id ===
#   Unique values: 246745
#   Most frequent: fe8fdbf582309c2b858dab336bbbd5208524b0f0663d40c2d1a6d16066fa0aa7
#   Top 5 value counts:
# shape: (5, 2)
# ┌─────────────────────────────────┬───────┐
# │ ad_id                           ┆ count │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ 3127e154f7440fb370465ed9a19998… ┆ 1     │
# │ 9d27b9558bd90e882eff27d36f3673… ┆ 1     │
# │ d1d942203827290e9fed1c8e56be31… ┆ 1     │
# │ 8ae33782035ceed2fcf3eb9d296c57… ┆ 1     │
# │ cb83b3d2ca8fe8ba216c074a034383… ┆ 1     │
# └─────────────────────────────────┴───────┘
#
# === Column: ad_creation_time ===
#   Unique values: 547
#   Most frequent: 2024-10-27
#   Top 5 value counts:
# shape: (5, 2)
# ┌──────────────────┬───────┐
# │ ad_creation_time ┆ count │
# │ ---              ┆ ---   │
# │ str              ┆ u32   │
# ╞══════════════════╪═══════╡
# │ 2024-10-27       ┆ 8619  │
# │ 2024-10-28       ┆ 7356  │
# │ 2024-10-26       ┆ 6414  │
# │ 2024-10-23       ┆ 5021  │
# │ 2024-10-25       ┆ 4769  │
# └──────────────────┴───────┘
#
# === Column: bylines ===
#   Unique values: 3791
#   Most frequent: HARRIS FOR PRESIDENT
#   Top 5 value counts:
# shape: (5, 2)
# ┌─────────────────────────────────┬───────┐
# │ bylines                         ┆ count │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ HARRIS FOR PRESIDENT            ┆ 49788 │
# │ HARRIS VICTORY FUND             ┆ 32612 │
# │ BIDEN VICTORY FUND              ┆ 15539 │
# │ DONALD J. TRUMP FOR PRESIDENT … ┆ 15112 │
# │ Trump National Committee JFC    ┆ 7279  │
# └─────────────────────────────────┴───────┘
#
# === Column: currency ===
#   Unique values: 18
#   Most frequent: USD
#   Top 5 value counts:
# shape: (5, 2)
# ┌──────────┬────────┐
# │ currency ┆ count  │
# │ ---      ┆ ---    │
# │ str      ┆ u32    │
# ╞══════════╪════════╡
# │ USD      ┆ 246599 │
# │ INR      ┆ 63     │
# │ GBP      ┆ 17     │
# │ EUR      ┆ 11     │
# │ EGP      ┆ 8      │
# └──────────┴────────┘
#
# === Column: delivery_by_region ===
#   Unique values: 141122
#   Most frequent: {}
#   Top 5 value counts:
# shape: (5, 2)
# ┌─────────────────────────────────┬───────┐
# │ delivery_by_region              ┆ count │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ {}                              ┆ 30989 │
# │ {'Georgia': {'spend': 49, 'imp… ┆ 2307  │
# │ {'Arizona': {'spend': 49, 'imp… ┆ 2020  │
# │ {'Pennsylvania': {'spend': 49,… ┆ 1912  │
# │ {'Nevada': {'spend': 49, 'impr… ┆ 1870  │
# └─────────────────────────────────┴───────┘
#
# === Column: demographic_distribution ===
#   Unique values: 215622
#   Most frequent: {}
#   Top 5 value counts:
# shape: (5, 2)
# ┌─────────────────────────────────┬───────┐
# │ demographic_distribution        ┆ count │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ {}                              ┆ 30989 │
# │ {'female_65+': {'spend': 49, '… ┆ 44    │
# │ {'male_65+': {'spend': 49, 'im… ┆ 24    │
# │ {'female_65+': {'spend': 49, '… ┆ 13    │
# │ {'female_65+': {'spend': 49, '… ┆ 12    │
# └─────────────────────────────────┴───────┘
#
# === Column: publisher_platforms ===
#   Unique values: 9
#   Most frequent: ['facebook', 'instagram']
#   Top 5 value counts:
# shape: (5, 2)
# ┌─────────────────────────────────┬────────┐
# │ publisher_platforms             ┆ count  │
# │ ---                             ┆ ---    │
# │ str                             ┆ u32    │
# ╞═════════════════════════════════╪════════╡
# │ ['facebook', 'instagram']       ┆ 214434 │
# │ ['facebook']                    ┆ 23259  │
# │ ['instagram']                   ┆ 8395   │
# │ ['facebook', 'instagram', 'aud… ┆ 459    │
# │ ['facebook', 'instagram', 'aud… ┆ 79     │
# └─────────────────────────────────┴────────┘
#
# === Column: illuminating_scored_message ===
#   Unique values: 26338
#   Most frequent: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
#   Top 5 value counts:
# shape: (5, 2)
# ┌─────────────────────────────────┬───────┐
# │ illuminating_scored_message     ┆ count │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ e3b0c44298fc1c149afbf4c8996fb9… ┆ 5972  │
# │ 82459467ad44f717f2089911f5210c… ┆ 1887  │
# │ 3b1d236346df93fd259a23d523f6de… ┆ 1352  │
# │ 7e119dac6ca701d8070d0ca8c5b480… ┆ 1341  │
# │ 8e1144f0b13549c2652e19f6dd1ae5… ┆ 1172  │
# └─────────────────────────────────┴───────┘
#
# === Column: illuminating_mentions ===
#   Unique values: 278
#   Most frequent: []
#   Top 5 value counts:
# shape: (5, 2)
# ┌───────────────────────┬───────┐
# │ illuminating_mentions ┆ count │
# │ ---                   ┆ ---   │
# │ str                   ┆ u32   │
# ╞═══════════════════════╪═══════╡
# │ []                    ┆ 73205 │
# │ ['Donald Trump']      ┆ 53182 │
# │ ['Kamala Harris']     ┆ 31019 │
# │ ['President Trump']   ┆ 14580 │
# │ ['Joe Biden']         ┆ 14059 │
# └───────────────────────┴───────┘

# %%
import polars as pl

# Load your CSV into a Polars DataFrame
df = pl.read_csv("2024_fb_ads_president_scored_anon.csv")

# Identify numeric columns (floats and integers)
numeric_cols = [col for col, dtype in zip(df.columns, df.dtypes) if dtype in [pl.Float64, pl.Float32, pl.Int64, pl.Int32]]

print("=== NUMERIC COLUMNS SUMMARY ===\n")

for col in numeric_cols:
    series = df[col]
    # Drop nulls (if any)
    non_null = series.drop_nulls()
    count = non_null.len()
    mean = non_null.mean()
    minv = non_null.min()
    maxv = non_null.max()
    std = non_null.std()
    q25 = non_null.quantile(0.25, "nearest")
    q50 = non_null.median()
    q75 = non_null.quantile(0.75, "nearest")
    print(f"{col}:")
    print(f"  Count: {count}")
    print(f"  Mean: {mean:.3f}")
    print(f"  Min: {minv:.3f}")
    print(f"  Max: {maxv:.3f}")
    print(f"  Std: {std:.3f}")
    print(f"  25%: {q25:.3f}")
    print(f"  50%: {q50:.3f}")
    print(f"  75%: {q75:.3f}\n")
# Out:
# === NUMERIC COLUMNS SUMMARY ===
#
# estimated_audience_size:
#   Count: 246745
#   Mean: 556462.856
#   Min: 0.000
#   Max: 1000001.000
#   Std: 409864.759
#   25%: 75000.000
#   50%: 300000.000
#   75%: 1000001.000
#
# estimated_impressions:
#   Count: 246745
#   Mean: 45601.526
#   Min: 499.000
#   Max: 1000000.000
#   Std: 136790.770
#   25%: 499.000
#   50%: 3499.000
#   75%: 22499.000
#
# estimated_spend:
#   Count: 246745
#   Mean: 1061.291
#   Min: 49.000
#   Max: 474999.000
#   Std: 4992.561
#   25%: 49.000
#   50%: 49.000
#   75%: 449.000
#
# scam_illuminating:
#   Count: 246745
#   Mean: 0.072
#   Min: 0.000
#   Max: 1.000
#   Std: 0.258
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# election_integrity_Truth_illuminating:
#   Count: 246745
#   Mean: 0.050
#   Min: 0.000
#   Max: 1.000
#   Std: 0.218
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# advocacy_msg_type_illuminating:
#   Count: 246745
#   Mean: 0.549
#   Min: 0.000
#   Max: 1.000
#   Std: 0.498
#   25%: 0.000
#   50%: 1.000
#   75%: 1.000
#
# issue_msg_type_illuminating:
#   Count: 246745
#   Mean: 0.382
#   Min: 0.000
#   Max: 1.000
#   Std: 0.486
#   25%: 0.000
#   50%: 0.000
#   75%: 1.000
#
# attack_msg_type_illuminating:
#   Count: 246745
#   Mean: 0.272
#   Min: 0.000
#   Max: 1.000
#   Std: 0.445
#   25%: 0.000
#   50%: 0.000
#   75%: 1.000
#
# image_msg_type_illuminating:
#   Count: 246745
#   Mean: 0.223
#   Min: 0.000
#   Max: 1.000
#   Std: 0.416
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# cta_msg_type_illuminating:
#   Count: 246745
#   Mean: 0.573
#   Min: 0.000
#   Max: 1.000
#   Std: 0.495
#   25%: 0.000
#   50%: 1.000
#   75%: 1.000
#
# engagement_cta_subtype_illuminating:
#   Count: 246745
#   Mean: 0.125
#   Min: 0.000
#   Max: 1.000
#   Std: 0.331
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# fundraising_cta_subtype_illuminating:
#   Count: 246745
#   Mean: 0.228
#   Min: 0.000
#   Max: 1.000
#   Std: 0.420
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# voting_cta_subtype_illuminating:
#   Count: 246745
#   Mean: 0.144
#   Min: 0.000
#   Max: 1.000
#   Std: 0.351
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# covid_topic_illuminating:
#   Count: 246745
#   Mean: 0.025
#   Min: 0.000
#   Max: 1.000
#   Std: 0.156
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# economy_topic_illuminating:
#   Count: 246745
#   Mean: 0.122
#   Min: 0.000
#   Max: 1.000
#   Std: 0.327
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# education_topic_illuminating:
#   Count: 246745
#   Mean: 0.014
#   Min: 0.000
#   Max: 1.000
#   Std: 0.119
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# environment_topic_illuminating:
#   Count: 246745
#   Mean: 0.021
#   Min: 0.000
#   Max: 1.000
#   Std: 0.144
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# foreign_policy_topic_illuminating:
#   Count: 246745
#   Mean: 0.005
#   Min: 0.000
#   Max: 1.000
#   Std: 0.072
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# governance_topic_illuminating:
#   Count: 246745
#   Mean: 0.026
#   Min: 0.000
#   Max: 1.000
#   Std: 0.158
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# health_topic_illuminating:
#   Count: 246745
#   Mean: 0.109
#   Min: 0.000
#   Max: 1.000
#   Std: 0.312
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# immigration_topic_illuminating:
#   Count: 246745
#   Mean: 0.034
#   Min: 0.000
#   Max: 1.000
#   Std: 0.180
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# lgbtq_issues_topic_illuminating:
#   Count: 246745
#   Mean: 0.003
#   Min: 0.000
#   Max: 1.000
#   Std: 0.057
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# military_topic_illuminating:
#   Count: 246745
#   Mean: 0.002
#   Min: 0.000
#   Max: 1.000
#   Std: 0.047
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# race_and_ethnicity_topic_illuminating:
#   Count: 246745
#   Mean: 0.012
#   Min: 0.000
#   Max: 1.000
#   Std: 0.111
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# safety_topic_illuminating:
#   Count: 246745
#   Mean: 0.034
#   Min: 0.000
#   Max: 1.000
#   Std: 0.181
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# social_and_cultural_topic_illuminating:
#   Count: 246745
#   Mean: 0.106
#   Min: 0.000
#   Max: 1.000
#   Std: 0.308
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# technology_and_privacy_topic_illuminating:
#   Count: 246745
#   Mean: 0.001
#   Min: 0.000
#   Max: 1.000
#   Std: 0.034
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# womens_issue_topic_illuminating:
#   Count: 246745
#   Mean: 0.081
#   Min: 0.000
#   Max: 1.000
#   Std: 0.273
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# incivility_illuminating:
#   Count: 246745
#   Mean: 0.188
#   Min: 0.000
#   Max: 1.000
#   Std: 0.390
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# freefair_illuminating:
#   Count: 246745
#   Mean: 0.006
#   Min: 0.000
#   Max: 1.000
#   Std: 0.080
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000
#
# fraud_illuminating:
#   Count: 246745
#   Mean: 0.003
#   Min: 0.000
#   Max: 1.000
#   Std: 0.051
#   25%: 0.000
#   50%: 0.000
#   75%: 0.000

# %% [markdown]
# **Descriptive Analytics: Python vs Pandas vs Polars**
#
# 1. Results: Are They Identical?
# All three methods—pure Python, Pandas, and Polars—produced identical summary statistics for both numeric and categorical columns. For numeric fields, the count, mean, min, max, standard deviation, and quartiles were exactly the same across tools. Categorical summaries (uniques, top values, frequency) were also fully consistent.
#
# Numeric Example
# Mean of estimated_audience_size:
#
# Python: 556462.856
#
# Pandas: 556462.856
#
# Polars: 556462.856
#
# Max of estimated_spend:
#
# Python: 474999
#
# Pandas: 474999
#
# Polars: 474999
#
# Categorical Example
# Most frequent page_id:
#
# All three: 4d66f5853f0365dba032a87704a634f023d15babde973bb7a284ed8cd2707b2d
#
# All three: 55,503 occurrences
#
# Conclusion
# For core summary statistics, all three approaches give identical answers—provided that data cleaning and preprocessing steps (e.g., converting string representations of lists/dicts) are handled the same way.
